# %%
from game_map_class import GameMap

# %%
import networkx as nx

# %% [markdown]
# ## Simple Map

# %%
ex_blocks = \
    {"1":
         ("red",
          ["A",
           "B",
           "C",
           "D"]
         ),
     "2":
         ("blue",
          ["E",
           "F"]
         ),
     "3":
         ("green"
          ,["G",
            "H",
            "I"]
         )
    }

# %%
ex_edges = [("A","B"),
            ("B","C"),
            ("C","D"),
            ("D","A"),
            ("B","E"),
            ("C","E"),
            ("E","F"),
            ("F","G"),
            ("G","H"),
            ("G","I")]

# %%
# In a real game you'd get actual GameTeams for your dict, but for demonstration we won't:
ex_teams = {'red':None,'blue':None}

# %%
simple_map = GameMap(ex_blocks,ex_edges,ex_teams)

# %%
list(simple_map.graph.nodes(data=True))
# Out:
# [('A', {'block': '1', 'team': None, 'num_troops': 0, 'neighbors': ['B', 'D']}),
#  ('B',
#   {'block': '1', 'team': None, 'num_troops': 0, 'neighbors': ['A', 'C', 'E']}),
#  ('C',
#   {'block': '1', 'team': None, 'num_troops': 0, 'neighbors': ['B', 'D', 'E']}),
#  ('D', {'block': '1', 'team': None, 'num_troops': 0, 'neighbors': ['C', 'A']}),
#  ('E',
#   {'block': '2', 'team': None, 'num_troops': 0, 'neighbors': ['B', 'C', 'F']}),
#  ('F', {'block': '2', 'team': None, 'num_troops': 0, 'neighbors': ['E', 'G']}),
#  ('G',
#   {'block': '3', 'team': None, 'num_troops': 0, 'neighbors': ['F', 'H', 'I']}),
#  ('H', {'block': '3', 'team': None, 'num_troops': 0, 'neighbors': ['G']}),
#  ('I', {'block': '3', 'team': None, 'num_troops': 0, 'neighbors': ['G']})]

# %%
list(simple_map.graph.edges())
# Out:
# [('A', 'B'),
#  ('A', 'D'),
#  ('B', 'C'),
#  ('B', 'E'),
#  ('C', 'D'),
#  ('C', 'E'),
#  ('E', 'F'),
#  ('F', 'G'),
#  ('G', 'H'),
#  ('G', 'I')]

# %%
nx.draw(simple_map.graph,with_labels=True)

# %% [markdown]
# ## Full Risk Map

# %%
risk_blocks = \
    {"North America":
         ("orange",
          ["Alaska",
            "North West Territory",
            "Alberta",
            "Ontario",
            "Quebec",
            "Western United States",
            "Eastern United States",
            "Central America",
            "Greenland"]
         ),

    "South America":
         ("yellow",
          ["Venezuela",
            "Brazil",
            "Peru",
            "Argentina"]
         ),

    "Europe":
         ("purple",
          ["Iceland",
            "Great Britain",
            "Western Europe",
            "Northern Europe",
            "Southern Europe",
            "Ukraine",
            "Scandinavia"]
         ),


    "Asia":
         ("green",
          ["Middle East",
            "Afghanistan",
            "Ural",
            "Siberia",
            "Yakutsk",
            "Irkutsk",
            "Mongolia",
            "China",
            "India",
            "Siam",
            "Kamchatka",
            "Japan"]
         ),

    "Australia":
         ("pink",
          ["Indonesia",
            "New Guinea",
            "Western Australia",
            "Eastern Australia"]
         ),

    "Africa":
         ("brown",
          ["Egypt",
           "North Africa",
           "East Africa",
           "Congo",
           "South Africa",
           "Madagascar"]
         )
    }

# %%
risk_edges = [("Alaska","North West Territory"),
              ("Alaska","Alberta"),
              ("Alaska","Kamchatka"),
              ("North West Territory","Alberta"),
              ("North West Territory","Ontario"),
              ("North West Territory","Greenland"),
              ("Alberta","Ontario"),
              ("Alberta","Western United States"),
              ("Ontario","Greenland"),
              ("Ontario","Quebec"),
              ("Ontario","Western United States"),
              ("Ontario","Eastern United States"),
              ("Greenland","Quebec"),
              ("Greenland","Iceland"),
              ("Quebec","Eastern United States"),
              ("Western United States","Eastern United States"),
              ("Western United States","Central America"),
              ("Eastern United States","Central America"),
              ("Central America","Venezuela"),
              ("Venezuela","Brazil"),
              ("Venezuela","Peru"),
              ("Brazil","Peru"),
              ("Brazil","Argentina"),
              ("Brazil","North Africa"),
              ("Peru","Argentina"),
              ("Iceland","Great Britain"),
              ("Iceland","Scandinavia"),
              ("Great Britain","Scandinavia"),
              ("Great Britain","Northern Europe"),
              ("Great Britain","Western Europe"),
              ("Western Europe","Northern Europe"),
              ("Western Europe","Southern Europe"),
              ("Western Europe","North Africa"),
              ("Northern Europe","Scandinavia"),
              ("Northern Europe","Southern Europe"),
              ("Northern Europe","Ukraine"),
              ("Southern Europe","Ukraine"),
              ("Southern Europe","Middle East"),
              ("Southern Europe","Egypt"),
              ("Southern Europe","North Africa"),
              ("Ukraine","Scandinavia"),
              ("Ukraine","Ural"),
              ("Ukraine","Afghanistan"),
              ("Ukraine","Middle East"),
              ("Egypt","Middle East"),
              ("Egypt","East Africa"),
              ("Egypt","North Africa"),
              ("North Africa","East Africa"),
              ("North Africa","Congo"),
              ("East Africa","Middle East"),
              ("East Africa","Madagascar"),
              ("East Africa","South Africa"),
              ("East Africa","Congo"),
              ("Congo","South Africa"),
              ("South Africa","Madagascar"),
              ("Middle East","Afghanistan"),
              ("Middle East","India"),
              ("Afghanistan","Ural"),
              ("Afghanistan","China"),
              ("Afghanistan","India"),
              ("Ural","Siberia"),
              ("Ural","China"),
              ("Siberia","Yakutsk"),
              ("Siberia","Irkutsk"),
              ("Siberia","Mongolia"),
              ("Siberia","China"),
              ("Yakutsk","Kamchatka"),
              ("Yakutsk","Irkutsk"),
              ("Irkutsk","Kamchatka"),
              ("Irkutsk","Mongolia"),
              ("Mongolia","China"),
              ("Mongolia","Kamchatka"),
              ("Mongolia","Japan"),
              ("China","Siam"),
              ("China","India"),
              ("India","Siam"),
              ("Siam","Indonesia"),
              ("Kamchatka","Japan"),
              ("Indonesia","New Guinea"),
              ("Indonesia","Western Australia"),
              ("New Guinea","Western Australia"),
              ("New Guinea","Eastern Australia"),
              ("Western Australia","Eastern Australia")]

# %%
# In a real game you'd get actual GameTeams for your dict, but for demonstration we won't:
risk_teams = {'red':None,'blue':None}

# %%
full_risk_map = GameMap(risk_blocks,risk_edges,risk_teams)

# %%
list(full_risk_map.graph.nodes(data=True))
# Out:
# [('Alaska',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['North West Territory', 'Alberta', 'Kamchatka']}),
#  ('North West Territory',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Alaska', 'Alberta', 'Ontario', 'Greenland']}),
#  ('Alberta',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Alaska',
#     'North West Territory',
#     'Ontario',
#     'Western United States']}),
#  ('Ontario',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['North West Territory',
#     'Alberta',
#     'Greenland',
#     'Quebec',
#     'Western United States',
#     'Eastern United States']}),
#  ('Quebec',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Ontario', 'Greenland', 'Eastern United States']}),
#  ('Western United States',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Alberta',
#     'Ontario',
#     'Eastern United States',
#     'Central America']}),
#  ('Eastern United States',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Ontario',
#     'Quebec',
#     'Western United States',
#     'Central America']}),
#  ('Central America',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Western United States',
#     'Eastern United States',
#     'Venezuela']}),
#  ('Greenland',
#   {'block': 'North America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['North West Territory', 'Ontario', 'Quebec', 'Iceland']}),
#  ('Venezuela',
#   {'block': 'South America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Central America', 'Brazil', 'Peru']}),
#  ('Brazil',
#   {'block': 'South America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Venezuela', 'Peru', 'Argentina', 'North Africa']}),
#  ('Peru',
#   {'block': 'South America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Venezuela', 'Brazil', 'Argentina']}),
#  ('Argentina',
#   {'block': 'South America',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Brazil', 'Peru']}),
#  ('Iceland',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Greenland', 'Great Britain', 'Scandinavia']}),
#  ('Great Britain',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Iceland',
#     'Scandinavia',
#     'Northern Europe',
#     'Western Europe']}),
#  ('Western Europe',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Great Britain',
#     'Northern Europe',
#     'Southern Europe',
#     'North Africa']}),
#  ('Northern Europe',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Great Britain',
#     'Western Europe',
#     'Scandinavia',
#     'Southern Europe',
#     'Ukraine']}),
#  ('Southern Europe',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Western Europe',
#     'Northern Europe',
#     'Ukraine',
#     'Middle East',
#     'Egypt',
#     'North Africa']}),
#  ('Ukraine',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Northern Europe',
#     'Southern Europe',
#     'Scandinavia',
#     'Ural',
#     'Afghanistan',
#     'Middle East']}),
#  ('Scandinavia',
#   {'block': 'Europe',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Iceland', 'Great Britain', 'Northern Europe', 'Ukraine']}),
#  ('Middle East',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Southern Europe',
#     'Ukraine',
#     'Egypt',
#     'East Africa',
#     'Afghanistan',
#     'India']}),
#  ('Afghanistan',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Ukraine', 'Middle East', 'Ural', 'China', 'India']}),
#  ('Ural',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Ukraine', 'Afghanistan', 'Siberia', 'China']}),
#  ('Siberia',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Ural', 'Yakutsk', 'Irkutsk', 'Mongolia', 'China']}),
#  ('Yakutsk',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Siberia', 'Kamchatka', 'Irkutsk']}),
#  ('Irkutsk',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Siberia', 'Yakutsk', 'Kamchatka', 'Mongolia']}),
#  ('Mongolia',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Siberia', 'Irkutsk', 'China', 'Kamchatka', 'Japan']}),
#  ('China',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Afghanistan',
#     'Ural',
#     'Siberia',
#     'Mongolia',
#     'Siam',
#     'India']}),
#  ('India',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Middle East', 'Afghanistan', 'China', 'Siam']}),
#  ('Siam',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['China', 'India', 'Indonesia']}),
#  ('Kamchatka',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Alaska', 'Yakutsk', 'Irkutsk', 'Mongolia', 'Japan']}),
#  ('Japan',
#   {'block': 'Asia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Mongolia', 'Kamchatka']}),
#  ('Indonesia',
#   {'block': 'Australia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Siam', 'New Guinea', 'Western Australia']}),
#  ('New Guinea',
#   {'block': 'Australia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Indonesia', 'Western Australia', 'Eastern Australia']}),
#  ('Western Australia',
#   {'block': 'Australia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Indonesia', 'New Guinea', 'Eastern Australia']}),
#  ('Eastern Australia',
#   {'block': 'Australia',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['New Guinea', 'Western Australia']}),
#  ('Egypt',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Southern Europe',
#     'Middle East',
#     'East Africa',
#     'North Africa']}),
#  ('North Africa',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Brazil',
#     'Western Europe',
#     'Southern Europe',
#     'Egypt',
#     'East Africa',
#     'Congo']}),
#  ('East Africa',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['Egypt',
#     'North Africa',
#     'Middle East',
#     'Madagascar',
#     'South Africa',
#     'Congo']}),
#  ('Congo',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['North Africa', 'East Africa', 'South Africa']}),
#  ('South Africa',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['East Africa', 'Congo', 'Madagascar']}),
#  ('Madagascar',
#   {'block': 'Africa',
#    'team': None,
#    'num_troops': 0,
#    'neighbors': ['East Africa', 'South Africa']})]

# %%
list(full_risk_map.graph.edges())
# Out:
# [('Alaska', 'North West Territory'),
#  ('Alaska', 'Alberta'),
#  ('Alaska', 'Kamchatka'),
#  ('North West Territory', 'Alberta'),
#  ('North West Territory', 'Ontario'),
#  ('North West Territory', 'Greenland'),
#  ('Alberta', 'Ontario'),
#  ('Alberta', 'Western United States'),
#  ('Ontario', 'Greenland'),
#  ('Ontario', 'Quebec'),
#  ('Ontario', 'Western United States'),
#  ('Ontario', 'Eastern United States'),
#  ('Quebec', 'Greenland'),
#  ('Quebec', 'Eastern United States'),
#  ('Western United States', 'Eastern United States'),
#  ('Western United States', 'Central America'),
#  ('Eastern United States', 'Central America'),
#  ('Central America', 'Venezuela'),
#  ('Greenland', 'Iceland'),
#  ('Venezuela', 'Brazil'),
#  ('Venezuela', 'Peru'),
#  ('Brazil', 'Peru'),
#  ('Brazil', 'Argentina'),
#  ('Brazil', 'North Africa'),
#  ('Peru', 'Argentina'),
#  ('Iceland', 'Great Britain'),
#  ('Iceland', 'Scandinavia'),
#  ('Great Britain', 'Scandinavia'),
#  ('Great Britain', 'Northern Europe'),
#  ('Great Britain', 'Western Europe'),
#  ('Western Europe', 'Northern Europe'),
#  ('Western Europe', 'Southern Europe'),
#  ('Western Europe', 'North Africa'),
#  ('Northern Europe', 'Scandinavia'),
#  ('Northern Europe', 'Southern Europe'),
#  ('Northern Europe', 'Ukraine'),
#  ('Southern Europe', 'Ukraine'),
#  ('Southern Europe', 'Middle East'),
#  ('Southern Europe', 'Egypt'),
#  ('Southern Europe', 'North Africa'),
#  ('Ukraine', 'Scandinavia'),
#  ('Ukraine', 'Ural'),
#  ('Ukraine', 'Afghanistan'),
#  ('Ukraine', 'Middle East'),
#  ('Middle East', 'Egypt'),
#  ('Middle East', 'East Africa'),
#  ('Middle East', 'Afghanistan'),
#  ('Middle East', 'India'),
#  ('Afghanistan', 'Ural'),
#  ('Afghanistan', 'China'),
#  ('Afghanistan', 'India'),
#  ('Ural', 'Siberia'),
#  ('Ural', 'China'),
#  ('Siberia', 'Yakutsk'),
#  ('Siberia', 'Irkutsk'),
#  ('Siberia', 'Mongolia'),
#  ('Siberia', 'China'),
#  ('Yakutsk', 'Kamchatka'),
#  ('Yakutsk', 'Irkutsk'),
#  ('Irkutsk', 'Kamchatka'),
#  ('Irkutsk', 'Mongolia'),
#  ('Mongolia', 'China'),
#  ('Mongolia', 'Kamchatka'),
#  ('Mongolia', 'Japan'),
#  ('China', 'Siam'),
#  ('China', 'India'),
#  ('India', 'Siam'),
#  ('Siam', 'Indonesia'),
#  ('Kamchatka', 'Japan'),
#  ('Indonesia', 'New Guinea'),
#  ('Indonesia', 'Western Australia'),
#  ('New Guinea', 'Western Australia'),
#  ('New Guinea', 'Eastern Australia'),
#  ('Western Australia', 'Eastern Australia'),
#  ('Egypt', 'East Africa'),
#  ('Egypt', 'North Africa'),
#  ('North Africa', 'East Africa'),
#  ('North Africa', 'Congo'),
#  ('East Africa', 'Madagascar'),
#  ('East Africa', 'South Africa'),
#  ('East Africa', 'Congo'),
#  ('Congo', 'South Africa'),
#  ('South Africa', 'Madagascar')]

# %%
# clearly this is ugly will need to work on this
nx.draw(full_risk_map.graph,with_labels=True)
