# %%
from game_map_class import GameMap

# %%
import networkx as nx

# %% [markdown]
# ## Simple Map

# %%
ex_blocks = \
    {"1":
         ("red",
          ["A",
           "B",
           "C",
           "D"]
         ),
     "2":
         ("blue",
          ["E",
           "F"]
         ),
     "3":
         ("green"
          ,["G",
            "H",
            "I"]
         )
    }

# %%
ex_edges = [("A","B"),
            ("B","C"),
            ("C","D"),
            ("D","A"),
            ("B","E"),
            ("C","E"),
            ("E","F"),
            ("F","G"),
            ("G","H"),
            ("G","I")]

# %%
simple_map = GameMap(ex_blocks,ex_edges)

# %%
list(simple_map.graph.nodes(data=True))
# Out:
# [('A', {'block': '1', 'team': None, 'num_troops': 0}),
#  ('B', {'block': '1', 'team': None, 'num_troops': 0}),
#  ('C', {'block': '1', 'team': None, 'num_troops': 0}),
#  ('D', {'block': '1', 'team': None, 'num_troops': 0}),
#  ('E', {'block': '2', 'team': None, 'num_troops': 0}),
#  ('F', {'block': '2', 'team': None, 'num_troops': 0}),
#  ('G', {'block': '3', 'team': None, 'num_troops': 0}),
#  ('H', {'block': '3', 'team': None, 'num_troops': 0}),
#  ('I', {'block': '3', 'team': None, 'num_troops': 0})]

# %%
list(simple_map.graph.edges())
# Out:
# [('A', 'B'),
#  ('A', 'D'),
#  ('B', 'C'),
#  ('B', 'E'),
#  ('C', 'D'),
#  ('C', 'E'),
#  ('E', 'F'),
#  ('F', 'G'),
#  ('G', 'H'),
#  ('G', 'I')]

# %%
nx.draw(simple_map.graph,with_labels=True)

# %% [markdown]
# ## Full Risk Map

# %%
risk_blocks = \
    {"North America":
         ("orange",
          ["Alaska",
            "North West Territory",
            "Alberta",
            "Ontario",
            "Quebec",
            "Western United States",
            "Eastern United States",
            "Central America",
            "Greenland"]
         ),

    "South America":
         ("yellow",
          ["Venezuela",
            "Brazil",
            "Peru",
            "Argentina"]
         ),

    "Europe":
         ("purple",
          ["Iceland",
            "Great Britain",
            "Western Europe",
            "Northern Europe",
            "Southern Europe",
            "Ukraine",
            "Scandinavia"]
         ),


    "Asia":
         ("green",
          ["Middle East",
            "Afghanistan",
            "Ural",
            "Siberia",
            "Yakutsk",
            "Irkutsk",
            "Mongolia",
            "China",
            "India",
            "Siam",
            "Kamchatka",
            "Japan"]
         ),

    "Australia":
         ("pink",
          ["Indonesia",
            "New Guinea",
            "Western Australia",
            "Eastern Australia"]
         ),

    "Africa":
         ("brown",
          ["Egypt",
           "North Africa",
           "East Africa",
           "Congo",
           "South Africa",
           "Madagascar"]
         )
    }

# %%
risk_edges = [("Alaska","North West Territory"),
              ("Alaska","Alberta"),
              ("Alaska","Kamchatka"),
              ("North West Territory","Alberta"),
              ("North West Territory","Ontario"),
              ("North West Territory","Greenland"),
              ("Alberta","Ontario"),
              ("Alberta","Western United States"),
              ("Ontario","Greenland"),
              ("Ontario","Quebec"),
              ("Ontario","Western United States"),
              ("Ontario","Eastern United States"),
              ("Greenland","Quebec"),
              ("Greenland","Iceland"),
              ("Quebec","Eastern United States"),
              ("Western United States","Eastern United States"),
              ("Western United States","Central America"),
              ("Eastern United States","Central America"),
              ("Central America","Venezuela"),
              ("Venezuela","Brazil"),
              ("Venezuela","Peru"),
              ("Brazil","Peru"),
              ("Brazil","Argentina"),
              ("Brazil","North Africa"),
              ("Peru","Argentina"),
              ("Iceland","Great Britain"),
              ("Iceland","Scandinavia"),
              ("Great Britain","Scandinavia"),
              ("Great Britain","Northern Europe"),
              ("Great Britain","Western Europe"),
              ("Western Europe","Northern Europe"),
              ("Western Europe","Southern Europe"),
              ("Western Europe","North Africa"),
              ("Northern Europe","Scandinavia"),
              ("Northern Europe","Southern Europe"),
              ("Northern Europe","Ukraine"),
              ("Southern Europe","Ukraine"),
              ("Southern Europe","Middle East"),
              ("Southern Europe","Egypt"),
              ("Southern Europe","North Africa"),
              ("Ukraine","Scandinavia"),
              ("Ukraine","Ural"),
              ("Ukraine","Afghanistan"),
              ("Ukraine","Middle East"),
              ("Egypt","Middle East"),
              ("Egypt","East Africa"),
              ("Egypt","North Africa"),
              ("North Africa","East Africa"),
              ("North Africa","Congo"),
              ("East Africa","Middle East"),
              ("East Africa","Madagascar"),
              ("East Africa","South Africa"),
              ("East Africa","Congo"),
              ("Congo","South Africa"),
              ("South Africa","Madagascar"),
              ("Middle East","Afghanistan"),
              ("Middle East","India"),
              ("Afghanistan","Ural"),
              ("Afghanistan","China"),
              ("Afghanistan","India"),
              ("Ural","Siberia"),
              ("Ural","China"),
              ("Siberia","Yakutsk"),
              ("Siberia","Irkutsk"),
              ("Siberia","Mongolia"),
              ("Siberia","China"),
              ("Yakutsk","Kamchatka"),
              ("Yakutsk","Irkutsk"),
              ("Irkutsk","Kamchatka"),
              ("Irkutsk","Mongolia"),
              ("Mongolia","China"),
              ("Mongolia","Kamchatka"),
              ("Mongolia","Japan"),
              ("China","Siam"),
              ("China","India"),
              ("India","Siam"),
              ("Siam","Indonesia"),
              ("Kamchatka","Japan"),
              ("Indonesia","New Guinea"),
              ("Indonesia","Western Australia"),
              ("New Guinea","Western Australia"),
              ("New Guinea","Eastern Australia"),
              ("Western Australia","Eastern Australia")]

# %%
full_risk_map = GameMap(risk_blocks,risk_edges)

# %%
list(full_risk_map.graph.nodes(data=True))
# Out:
# [('Alaska', {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('North West Territory',
#   {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Alberta', {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Ontario', {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Quebec', {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Western United States',
#   {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Eastern United States',
#   {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Central America',
#   {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Greenland', {'block': 'North America', 'team': None, 'num_troops': 0}),
#  ('Venezuela', {'block': 'South America', 'team': None, 'num_troops': 0}),
#  ('Brazil', {'block': 'South America', 'team': None, 'num_troops': 0}),
#  ('Peru', {'block': 'South America', 'team': None, 'num_troops': 0}),
#  ('Argentina', {'block': 'South America', 'team': None, 'num_troops': 0}),
#  ('Iceland', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Great Britain', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Western Europe', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Northern Europe', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Southern Europe', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Ukraine', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Scandinavia', {'block': 'Europe', 'team': None, 'num_troops': 0}),
#  ('Middle East', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Afghanistan', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Ural', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Siberia', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Yakutsk', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Irkutsk', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Mongolia', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('China', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('India', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Siam', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Kamchatka', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Japan', {'block': 'Asia', 'team': None, 'num_troops': 0}),
#  ('Indonesia', {'block': 'Australia', 'team': None, 'num_troops': 0}),
#  ('New Guinea', {'block': 'Australia', 'team': None, 'num_troops': 0}),
#  ('Western Australia', {'block': 'Australia', 'team': None, 'num_troops': 0}),
#  ('Eastern Australia', {'block': 'Australia', 'team': None, 'num_troops': 0}),
#  ('Egypt', {'block': 'Africa', 'team': None, 'num_troops': 0}),
#  ('North Africa', {'block': 'Africa', 'team': None, 'num_troops': 0}),
#  ('East Africa', {'block': 'Africa', 'team': None, 'num_troops': 0}),
#  ('Congo', {'block': 'Africa', 'team': None, 'num_troops': 0}),
#  ('South Africa', {'block': 'Africa', 'team': None, 'num_troops': 0}),
#  ('Madagascar', {'block': 'Africa', 'team': None, 'num_troops': 0})]

# %%
list(full_risk_map.graph.edges())
# Out:
# [('Alaska', 'North West Territory'),
#  ('Alaska', 'Alberta'),
#  ('Alaska', 'Kamchatka'),
#  ('North West Territory', 'Alberta'),
#  ('North West Territory', 'Ontario'),
#  ('North West Territory', 'Greenland'),
#  ('Alberta', 'Ontario'),
#  ('Alberta', 'Western United States'),
#  ('Ontario', 'Greenland'),
#  ('Ontario', 'Quebec'),
#  ('Ontario', 'Western United States'),
#  ('Ontario', 'Eastern United States'),
#  ('Quebec', 'Greenland'),
#  ('Quebec', 'Eastern United States'),
#  ('Western United States', 'Eastern United States'),
#  ('Western United States', 'Central America'),
#  ('Eastern United States', 'Central America'),
#  ('Central America', 'Venezuela'),
#  ('Greenland', 'Iceland'),
#  ('Venezuela', 'Brazil'),
#  ('Venezuela', 'Peru'),
#  ('Brazil', 'Peru'),
#  ('Brazil', 'Argentina'),
#  ('Brazil', 'North Africa'),
#  ('Peru', 'Argentina'),
#  ('Iceland', 'Great Britain'),
#  ('Iceland', 'Scandinavia'),
#  ('Great Britain', 'Scandinavia'),
#  ('Great Britain', 'Northern Europe'),
#  ('Great Britain', 'Western Europe'),
#  ('Western Europe', 'Northern Europe'),
#  ('Western Europe', 'Southern Europe'),
#  ('Western Europe', 'North Africa'),
#  ('Northern Europe', 'Scandinavia'),
#  ('Northern Europe', 'Southern Europe'),
#  ('Northern Europe', 'Ukraine'),
#  ('Southern Europe', 'Ukraine'),
#  ('Southern Europe', 'Middle East'),
#  ('Southern Europe', 'Egypt'),
#  ('Southern Europe', 'North Africa'),
#  ('Ukraine', 'Scandinavia'),
#  ('Ukraine', 'Ural'),
#  ('Ukraine', 'Afghanistan'),
#  ('Ukraine', 'Middle East'),
#  ('Middle East', 'Egypt'),
#  ('Middle East', 'East Africa'),
#  ('Middle East', 'Afghanistan'),
#  ('Middle East', 'India'),
#  ('Afghanistan', 'Ural'),
#  ('Afghanistan', 'China'),
#  ('Afghanistan', 'India'),
#  ('Ural', 'Siberia'),
#  ('Ural', 'China'),
#  ('Siberia', 'Yakutsk'),
#  ('Siberia', 'Irkutsk'),
#  ('Siberia', 'Mongolia'),
#  ('Siberia', 'China'),
#  ('Yakutsk', 'Kamchatka'),
#  ('Yakutsk', 'Irkutsk'),
#  ('Irkutsk', 'Kamchatka'),
#  ('Irkutsk', 'Mongolia'),
#  ('Mongolia', 'China'),
#  ('Mongolia', 'Kamchatka'),
#  ('Mongolia', 'Japan'),
#  ('China', 'Siam'),
#  ('China', 'India'),
#  ('India', 'Siam'),
#  ('Siam', 'Indonesia'),
#  ('Kamchatka', 'Japan'),
#  ('Indonesia', 'New Guinea'),
#  ('Indonesia', 'Western Australia'),
#  ('New Guinea', 'Western Australia'),
#  ('New Guinea', 'Eastern Australia'),
#  ('Western Australia', 'Eastern Australia'),
#  ('Egypt', 'East Africa'),
#  ('Egypt', 'North Africa'),
#  ('North Africa', 'East Africa'),
#  ('North Africa', 'Congo'),
#  ('East Africa', 'Madagascar'),
#  ('East Africa', 'South Africa'),
#  ('East Africa', 'Congo'),
#  ('Congo', 'South Africa'),
#  ('South Africa', 'Madagascar')]

# %%
# clearly this is ugly will need to work on this
nx.draw(full_risk_map.graph,with_labels=True)
