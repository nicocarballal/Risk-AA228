# %%
from utils.game_map_class import GameMap
from utils.game_team_class import GameTeam
from utils.strategy_class import Strategy, RandomStrategy
from utils.map_setup_functions import setGameBoardRandom, initializeFullRiskMap

# %%
import networkx as nx
import random

# %%
full_risk_map = initializeFullRiskMap()
team_names = ["red", "blue"]
risk_map, teams = setGameBoardRandom(team_names, full_risk_map, RandomStrategy)

# %%
teams[0].getTerritories()
# Out:
# ['Kamchatka',
#  'Peru',
#  'Indonesia',
#  'Yakutsk',
#  'Eastern Australia',
#  'Brazil',
#  'Alaska',
#  'Ontario',
#  'Madagascar',
#  'India',
#  'Eastern United States',
#  'Siam',
#  'Venezuela',
#  'Siberia',
#  'Congo',
#  'Egypt',
#  'Irkutsk',
#  'Quebec',
#  'Middle East',
#  'Alberta',
#  'Western United States']

# %%
teams[0].addTroops(teams[0].getTerritories()[0], 1)

# %%
teams[0].getNextMove()
# Out:
# ('Kamchatka', 'Japan')

# %%
teams[0].determineAndMakeMove()
# Out:
# Team red declares attack on Team blue from Kamchatka to Japan
# Attacking_dice:  [5]
# Defending_dice:  [1]
# [ True]
# Attacking Troops Left:  2
# Defending Troops Left:  0

# %%
teams[0].playTurn()
# Out:
# Team red declares attack on Team blue from Siberia to China
# Attacking_dice:  [5]
# Defending_dice:  [2]
# [ True]
# Attacking Troops Left:  2
# Defending Troops Left:  0
# Team red declares attack on Team red from Ontario to Eastern United States
# Attacking_dice:  [5]
# Defending_dice:  [4]
# [ True]
# Attacking Troops Left:  2
# Defending Troops Left:  0
